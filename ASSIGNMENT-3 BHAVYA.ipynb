# %% [markdown]
#  BHAVYA SRI DUGGINA

# %% [markdown]
# # PENGUIN CLASSIFICATION ANALYSIS

# %% [markdown]
# TASK1- Download the Dataset

# %% [markdown]
# TASK2 -Load the dataset into Notebook

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("C:/Users/91741/Downloads/penguins_size.csv")

# %%
df.head(10)
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 3  Adelie  Torgersen               NaN              NaN                NaN
# 4  Adelie  Torgersen              36.7             19.3              193.0
# 5  Adelie  Torgersen              39.3             20.6              190.0
# 6  Adelie  Torgersen              38.9             17.8              181.0
# 7  Adelie  Torgersen              39.2             19.6              195.0
# 8  Adelie  Torgersen              34.1             18.1              193.0
# 9  Adelie  Torgersen              42.0             20.2              190.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# ...

# %%
df.shape
# Out:
# (344, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   culmen_length_mm   342 non-null    float64
#  3   culmen_depth_mm    342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                334 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
df.isnull().any()
# Out:
# species              False
# island               False
# culmen_length_mm      True
# culmen_depth_mm       True
# flipper_length_mm     True
# body_mass_g           True
# sex                   True
# dtype: bool

# %% [markdown]
# TASK3 -Perform Visualizations

# %% [markdown]
# UNIVARIATE

# %%
sns.histplot(df.culmen_depth_mm,kde=True,color="green")
plt.title("CULMEN_DEPTH ANALYSIS")
plt.show()

# %%
plt.pie(df.species.value_counts(),labels=df.species.unique(),explode=[0,0,0.1],autopct="%1.1f%%",colors=["yellow",'green',"blue"]) 
plt.title("Species Distribution")
plt.show()

# %% [markdown]
# BIVARIATE

# %%
sns.lineplot(x=df.culmen_length_mm,y=df.flipper_length_mm)
plt.title("Culmen_length Vs Flipper_length")
plt.show()

# %%
sns.barplot(x=df.sex.value_counts().index,y=df.species.value_counts())
plt.title("SEX Vs Species")
# Out:
# Text(0.5, 1.0, 'SEX Vs Species')

# %% [markdown]
# MULTIVARIATE

# %%
sns.heatmap(df.corr(),annot=True,linecolor="white",linewidths=0.3,cmap='prism',cbar=False)
plt.show()
# Out:
# C:\Users\91741\AppData\Local\Temp\ipykernel_16508\2469300400.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True,linecolor="white",linewidths=0.3,cmap='prism',cbar=False)

# %%
sns.pairplot(df)
plt.show()

# %% [markdown]
# TASK4 -PERFORM DESCRIPTIVE STATISTICS

# %%
df.describe()
# Out:
#        culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g
# count        342.000000       342.000000         342.000000   342.000000
# mean          43.921930        17.151170         200.915205  4201.754386
# std            5.459584         1.974793          14.061714   801.954536
# min           32.100000        13.100000         172.000000  2700.000000
# 25%           39.225000        15.600000         190.000000  3550.000000
# 50%           44.450000        17.300000         197.000000  4050.000000
# 75%           48.500000        18.700000         213.000000  4750.000000
# max           59.600000        21.500000         231.000000  6300.000000

# %% [markdown]
# TASK5 - Check missing values and deal with them

# %%
df.isnull().sum()
# Out:
# species               0
# island                0
# culmen_length_mm      2
# culmen_depth_mm       2
# flipper_length_mm     2
# body_mass_g           2
# sex                  10
# dtype: int64

# %%
df.loc[df.culmen_length_mm.isnull()]
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 3    Adelie  Torgersen               NaN              NaN                NaN
# 339  Gentoo     Biscoe               NaN              NaN                NaN
#
#      body_mass_g  sex
# 3            NaN  NaN
# 339          NaN  NaN

# %%
df.culmen_length_mm.fillna(df.culmen_length_mm.median(),inplace=True)

# %%
df.culmen_length_mm.isnull().any()
# Out:
# False

# %%
df.loc[df.culmen_depth_mm.isnull()]
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 3    Adelie  Torgersen             44.45              NaN                NaN
# 339  Gentoo     Biscoe             44.45              NaN                NaN
#
#      body_mass_g  sex
# 3            NaN  NaN
# 339          NaN  NaN

# %%
df.culmen_depth_mm.fillna(df.culmen_depth_mm.median(),inplace=True)

# %%
df.culmen_depth_mm.isnull().any()
# Out:
# False

# %%
df.loc[df.flipper_length_mm.isnull()]
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 3    Adelie  Torgersen             44.45             17.3                NaN
# 339  Gentoo     Biscoe             44.45             17.3                NaN
#
#      body_mass_g  sex
# 3            NaN  NaN
# 339          NaN  NaN

# %%
df.flipper_length_mm.fillna(df.flipper_length_mm.median(),inplace=True)

# %%
df.flipper_length_mm.isnull().any()
# Out:
# False

# %%
df.loc[df.body_mass_g.isnull()]
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 3    Adelie  Torgersen             44.45             17.3              197.0
# 339  Gentoo     Biscoe             44.45             17.3              197.0
#
#      body_mass_g  sex
# 3            NaN  NaN
# 339          NaN  NaN

# %%
df.body_mass_g.fillna(df.body_mass_g.median(),inplace=True)

# %%
df.body_mass_g.isnull().any()
# Out:
# False

# %%
df.loc[df.sex.isnull()]
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 3    Adelie  Torgersen             44.45             17.3              197.0
# 8    Adelie  Torgersen             34.10             18.1              193.0
# 9    Adelie  Torgersen             42.00             20.2              190.0
# 10   Adelie  Torgersen             37.80             17.1              186.0
# 11   Adelie  Torgersen             37.80             17.3              180.0
# 47   Adelie      Dream             37.50             18.9              179.0
# 246  Gentoo     Biscoe             44.50             14.3              216.0
# 286  Gentoo     Biscoe             46.20             14.4              214.0
# 324  Gentoo     Biscoe             47.30             13.8              216.0
# 339  Gentoo     Biscoe             44.45             17.3              197.0
#
#      body_mass_g  sex
# 3         4050.0  NaN
# 8         3475.0  NaN
# 9         4250.0  NaN
# 10        3300.0  NaN
# ...

# %%
df.sex.fillna(df.sex.mode()[0],inplace=True)

# %%
df.sex.isnull().any()
# Out:
# False

# %%
df.isnull().sum()
# Out:
# species              0
# island               0
# culmen_length_mm     0
# culmen_depth_mm      0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# dtype: int64

# %% [markdown]
# TASK6 - Find Outliers

# %%
sns.boxplot(df.culmen_depth_mm)
# Out:
# <Axes: >

# %%
sns.boxplot(df.culmen_length_mm)
# Out:
# <Axes: >

# %%
sns.boxplot(df.flipper_length_mm)
# Out:
# <Axes: >

# %%
sns.boxplot(df.body_mass_g)
# Out:
# <Axes: >

# %% [markdown]
# TASK8 -Check for Categorical columns and perform encoding.

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df.species=le.fit_transform(df.species)
df.island=le.fit_transform(df.island)
df.sex=le.fit_transform(df.sex)

# %%
df.head()
# Out:
#    species  island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0        0       2             39.10             18.7              181.0
# 1        0       2             39.50             17.4              186.0
# 2        0       2             40.30             18.0              195.0
# 3        0       2             44.45             17.3              197.0
# 4        0       2             36.70             19.3              193.0
#
#    body_mass_g  sex
# 0       3750.0    2
# 1       3800.0    1
# 2       3250.0    1
# 3       4050.0    2
# 4       3450.0    1

# %%
TASK7 -Check the correlation of independent variables with the target
# Out:
#   Cell In[141], line 1
#     TASK7 -Check the correlation of independent variables with the target
#                  ^
# SyntaxError: invalid syntax

# %%
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
df.corr().species.sort_values(ascending=False)
# Out:
# species              1.000000
# flipper_length_mm    0.850819
# body_mass_g          0.747547
# culmen_length_mm     0.728706
# sex                 -0.003823
# island              -0.635659
# culmen_depth_mm     -0.741282
# Name: species, dtype: float64

# %% [markdown]
# TASK9 - Split the data into dependent and independent variables.

# %%
x=df.drop(columns=["species"],axis=1)

# %%
x
# Out:
#      island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0         2             39.10             18.7              181.0
# 1         2             39.50             17.4              186.0
# 2         2             40.30             18.0              195.0
# 3         2             44.45             17.3              197.0
# 4         2             36.70             19.3              193.0
# ..      ...               ...              ...                ...
# 339       0             44.45             17.3              197.0
# 340       0             46.80             14.3              215.0
# 341       0             50.40             15.7              222.0
# 342       0             45.20             14.8              212.0
# 343       0             49.90             16.1              213.0
#
#      body_mass_g  sex
# 0         3750.0    2
# 1         3800.0    1
# 2         3250.0    1
# 3         4050.0    2
# 4         3450.0    1
# ..           ...  ...
# ...

# %%
y=df.species

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 339    2
# 340    2
# 341    2
# 342    2
# 343    2
# Name: species, Length: 344, dtype: int32

# %% [markdown]
# TASK10 - Scaling the data

# %%
from sklearn.preprocessing import StandardScaler
S=StandardScaler()

# %%
xscale=pd.DataFrame(S.fit_transform(x),columns=x.columns)
xscale
# Out:
#        island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    1.844076         -0.887622         0.787289          -1.420541
# 1    1.844076         -0.814037         0.126114          -1.063485
# 2    1.844076         -0.666866         0.431272          -0.420786
# 3    1.844076          0.096581         0.075255          -0.277964
# 4    1.844076         -1.329133         1.092447          -0.563608
# ..        ...               ...              ...                ...
# 339 -0.914020          0.096581         0.075255          -0.277964
# 340 -0.914020          0.528894        -1.450534           1.007436
# 341 -0.914020          1.191161        -0.738500           1.507314
# 342 -0.914020          0.234553        -1.196236           0.793203
# 343 -0.914020          1.099179        -0.535061           0.864614
#
#      body_mass_g       sex
# 0      -0.564625  0.960230
# 1      -0.502010 -1.017729
# 2      -1.190773 -1.017729
# 3      -0.188936  0.960230
# ...

# %% [markdown]
# TASK-11 Split the data into training and testing

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(xscale,y,test_size=0.2,random_state=0 )

# %% [markdown]
# TASK12- check the training and testing data shape.

# %%
xtest.shape
# Out:
# (69, 6)

# %%
ytest.shape
# Out:
# (69,)

# %%
xtrain.shape
# Out:
# (275, 6)

# %%
ytrain.shape
# Out:
# (275,)

# %% [markdown]
# THANK YOU

# %% [markdown]
# BHAVYA SRI DUGGINA
